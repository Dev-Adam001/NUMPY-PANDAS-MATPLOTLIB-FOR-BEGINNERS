# %% [markdown]
# #matplotlib is an open-source drawing library which supports rich drawing types for drawing 2D and 3D graphics image

# %%
import os
import shutil as s

# %%
from matplotlib import pylab
print(pylab.__version__)
# Out:
# 1.21.5

# %%
import numpy as np
#np.array(np.random.randn())

a = np.linspace(0,10,25)
b = a*a+2
print(a)
print(b)
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]

# %%
print(np.array([a,b]).reshape(25,2))
# Out:
# [[  0.           0.41666667]
#  [  0.83333333   1.25      ]
#  [  1.66666667   2.08333333]
#  [  2.5          2.91666667]
#  [  3.33333333   3.75      ]
#  [  4.16666667   4.58333333]
#  [  5.           5.41666667]
#  [  5.83333333   6.25      ]
#  [  6.66666667   7.08333333]
#  [  7.5          7.91666667]
#  [  8.33333333   8.75      ]
#  [  9.16666667   9.58333333]
#  [ 10.           2.        ]
#  [  2.17361111   2.69444444]
#  [  3.5625       4.77777778]
#  [  6.34027778   8.25      ]
#  [ 10.50694444  13.11111111]
#  [ 16.0625      19.36111111]
#  [ 23.00694444  27.        ]
#  [ 31.34027778  36.02777778]
#  [ 41.0625      46.44444444]
#  [ 52.17361111  58.25      ]
#  [ 64.67361111  71.44444444]
#  [ 78.5625      86.02777778]
#  [ 93.84027778 102.        ]]

# %%
pylab.plot(a,b, 'b')

# %%
#Drawing a subgraph

pylab.subplot(1,2,1) #the contents in the brackets represent (rows, columns, indexes)
pylab.plot(a,b, 'b--') #the contents in the bracket detrermines colour and line types
pylab.subplot(1,2,2)
pylab.plot(b,a, 'y*-')

# %% [markdown]
# Operator description
#
# fig.add_axes() = initializes subplot a = fig.add_subplot(222)
#
# fig.b=plt.subplots(nrows=3, ncols=2) = Adds subplot
#
# ax = plt.subplots(2,2) = Creates subplot

# %%
from matplotlib import pyplot as plt

fig = plt.figure()
axis = fig.add_axes([0.5,0.1,0.8,0.8]) #control the left, right, width, height, width of the canvas from 0 to 1

axis.plot(a,b, 'b')

# %%
x = np.array([0,1,2,3,4,5])

fig, axes = plt.subplots(1, 4, figsize=(16,5))
axes[0].set_title('Scatter')
axes[0].scatter(x, x+0.25*np.random.randn(len(x)))

# %%
#Draw contour image

import matplotlib
import numpy as np
import matplotlib.cm as cm 
import matplotlib.pyplot as plt

delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X-1)**2 - (Y-1)**2)
Z = (Z1 - Z2) * 2

print(X)
print(Y)
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# [[-2.    -2.    -2.    ... -2.    -2.    -2.   ]
#  [-1.975 -1.975 -1.975 ... -1.975 -1.975 -1.975]
#  [-1.95  -1.95  -1.95  ... -1.95  -1.95  -1.95 ]
#  ...
#  [ 1.925  1.925  1.925 ...  1.925  1.925  1.925]
#  [ 1.95   1.95   1.95  ...  1.95   1.95   1.95 ]
#  [ 1.975  1.975  1.975 ...  1.975  1.975  1.975]]

# %%
fig, ax =plt.subplots()
CS = ax.contour(X, Y, Z)
ax.clabel(CS, inline=1, fontsize=10)
ax.set_title('contour map')
# Out:
# Text(0.5, 1.0, 'contour map')

# %%
#3D surface image
from mpl_toolkits.mplot3d.axes3d import Axes3D

fig = plt.figure(figsize=(14,6))

#specify the 3D graphics to draw, with projection-'3d'
ax = fig.add_subplot(1,1,1, projection='3d')

ax.plot_surface(X,Y,Z, rstride=4, cstride=4, linewidth=0)

# %%
languages = 'Python', 'Java', 'PHP', 'JavaScript', 'C#', 'C++'
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b']

# %%
#explode 1st slice

explode = (0.1, 0,0,0,0,0)
plt.pie(popularity, explode=explode, labels=languages, 
        colors=colors, autopct='%1.1f%%', 
        shadow=True, startangle=180)
# Out:
# ([<matplotlib.patches.Wedge at 0x163960cabb0>,
# ...
#  [Text(-0.6661322678714672, -0.9981321564304079, 'Python'),
#   Text(1.0139237282141302, -0.42656614184011227, 'Java'),
#   Text(0.7897694469856669, 0.7656789278855426, 'PHP'),
#   Text(0.06323929665114085, 1.0981806733680344, 'JavaScript'),
#   Text(-0.6544138527262939, 0.8841620379545418, 'C#'),
#   Text(-1.0520142924916656, 0.3213501647630831, 'C++')],
#  [Text(-0.3885771562583558, -0.5822437579177379, '31.3%'),
#   Text(0.5530493062986164, -0.23267244100369758, '24.8%'),
#   Text(0.4307833347194546, 0.4176430515739323, '12.4%'),
#   Text(0.03449416180971319, 0.5990076400189277, '11.3%'),
#   Text(-0.3569530105779785, 0.4822702025206591, '10.8%'),
#   Text(-0.5738259777227266, 0.17528190805259078, '9.4%')])

# %%
s.move("C:\\Users\\user\\Desktop\\SQL\\MATPLOTLIB TUTORIAL - unfinished.ipynb", "C:\\Users\\user\\Desktop\\PYTHON FOR DATA SCIENCE")
# Out:
# 'C:\\Users\\user\\Desktop\\PYTHON FOR DATA SCIENCE\\MATPLOTLIB TUTORIAL - unfinished.ipynb'
